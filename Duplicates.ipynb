# %%
import pandas as pd
df=pd.read_csv('Bakery sales.csv')
df.head()
# Out:
#    Unnamed: 0        date  time  ticket_number               article  \
# 0           0  2021-01-02  8:38         150040              BAGUETTE
# 1           1  2021-01-02  8:38         150040      PAIN AU CHOCOLAT
# 2           4  2021-01-02  9:14         150041      PAIN AU CHOCOLAT
# 3           5  2021-01-02  9:14         150041                  PAIN
# 4           8  2021-01-02  9:25         150042  TRADITIONAL BAGUETTE
#
#    Quantity unit_price
# 0         1     0,90 €
# 1         3     1,20 €
# 2         2     1,20 €
# 3         1     1,15 €
# 4         5     1,20 €

# %%
len(df[df[['article','date']].duplicated()])/len(df)
# Out:
# 0.8752077947052413

# %%
df[df[['article','date']].duplicated()]
# Out:
#         Unnamed: 0        date   time  ticket_number               article  \
# 2                4  2021-01-02   9:14         150041      PAIN AU CHOCOLAT
# 5               11  2021-01-02   9:25         150043              BAGUETTE
# 8               18  2021-01-02   9:32         150045  TRADITIONAL BAGUETTE
# 9               19  2021-01-02   9:32         150045             CROISSANT
# 10              22  2021-01-02   9:37         150046      PAIN AU CHOCOLAT
# ...            ...         ...    ...            ...                   ...
# 234000      511387  2022-09-30  18:52         288911                 COUPE
# 234001      511388  2022-09-30  18:52         288911            BOULE 200G
# 234002      511389  2022-09-30  18:52         288911                 COUPE
# 234003      511392  2022-09-30  18:55         288912  TRADITIONAL BAGUETTE
# 234004      511395  2022-09-30  18:56         288913  TRADITIONAL BAGUETTE
#
#         Quantity unit_price
# 2              2     1,20 €
# ...

# %%
df.shape
# Out:
# (234005, 7)

# %%
len(df['article'].drop_duplicates()) #149
# len(df['article'].drop_duplicates(keep=False)) #12
# Out:
# 149
