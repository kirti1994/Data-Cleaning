# %%
import pandas as pd
df=pd.read_csv('subway.csv')
df.head()
# Out:
#    index    name                                                url  \
# 0      0  Subway  http://order.subway.com/Stores/Redirect.aspx?s...
# 1      1  Subway  http://order.subway.com/Stores/Redirect.aspx?s...
# 2      2  Subway  http://order.subway.com/Stores/Redirect.aspx?s...
# 3      3  Subway  http://order.subway.com/Stores/Redirect.aspx?s...
# 4      4  Subway  http://order.subway.com/Stores/Redirect.aspx?s...
#
#                                    street_address        city state zip_code  \
# 0                           1800 Duke St, Ste 100  Alexandria    VA    22314
# 1                                   1512 King St,  Alexandria    VA    22301
# 2                            2361 Eisenhower Ave,  Alexandria    VA    22314
# 3                      320 King Street, 1st Floor  Alexandria    VA    22314
# 4  5836 N. Kings Hwy, Suite A, Huntington Station  Alexandria    VA    22303
#
#   country  phone_number_1  phone_number_2  ...  email_2  website  \
# ...

# %%
round(100.0*df.isna().sum()/len(df),2)
# Out:
# index               0.00
# name                0.00
# url                 5.94
# street_address      0.00
# city                0.00
# state               0.00
# zip_code            0.00
# country             0.00
# phone_number_1    100.00
# phone_number_2    100.00
# fax_1             100.00
# fax_2             100.00
# email_1           100.00
# email_2           100.00
# website           100.00
# open_hours          0.54
# latitude            0.00
# longitude           0.00
# facebook          100.00
# twitter           100.00
# instagram         100.00
# pinterest         100.00
# youtube           100.00
# dtype: float64

# %%
#Keep only the columns with atleast thresh non null values
#Drop columns which have more than thresh non null values
df.dropna(axis='columns',thresh=df.shape[0]/2)
# Out:
#        index    name                                                url  \
# 0          0  Subway  http://order.subway.com/Stores/Redirect.aspx?s...
# 1          1  Subway  http://order.subway.com/Stores/Redirect.aspx?s...
# 2          2  Subway  http://order.subway.com/Stores/Redirect.aspx?s...
# 3          3  Subway  http://order.subway.com/Stores/Redirect.aspx?s...
# 4          4  Subway  http://order.subway.com/Stores/Redirect.aspx?s...
# ...      ...     ...                                                ...
# 25528  25528  Subway  http://order.subway.com/Stores/Redirect.aspx?s...
# 25529  25529  Subway  http://order.subway.com/Stores/Redirect.aspx?s...
# 25530  25530  Subway  http://order.subway.com/Stores/Redirect.aspx?s...
# 25531  25531  Subway  http://order.subway.com/Stores/Redirect.aspx?s...
# 25532  25532  Subway  http://order.subway.com/Stores/Redirect.aspx?s...
#
#                                           street_address        city state  \
# ...

# %%
df.dropna(thresh=12)
# Out:
# Empty DataFrame
# Columns: [index, name, url, street_address, city, state, zip_code, country, phone_number_1, phone_number_2, fax_1, fax_2, email_1, email_2, website, open_hours, latitude, longitude, facebook, twitter, instagram, pinterest, youtube]
# Index: []
#
# [0 rows x 23 columns]

# %%
df.mean()
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# index             12766.000000
# phone_number_1             NaN
# phone_number_2             NaN
# fax_1                      NaN
# fax_2                      NaN
# email_1                    NaN
# email_2                    NaN
# website                    NaN
# latitude             37.347921
# longitude           -92.139107
# facebook                   NaN
# twitter                    NaN
# instagram                  NaN
# pinterest                  NaN
# youtube                    NaN
# dtype: float64

# %%
df.shape
# Out:
# (25533, 23)

# %%
df.median()
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# index             12766.0000
# phone_number_1           NaN
# phone_number_2           NaN
# fax_1                    NaN
# fax_2                    NaN
# email_1                  NaN
# email_2                  NaN
# website                  NaN
# latitude             38.1444
# longitude           -87.7554
# facebook                 NaN
# twitter                  NaN
# instagram                NaN
# pinterest                NaN
# youtube                  NaN
# dtype: float64

# %%
df.mode()['city'][0]
# Out:
# 'Houston'

# %%
df.city.unique()
# Out:
# array(['Alexandria', 'Washington', 'Arlington', ..., 'Silverdale',
#        'Bainbridge Island', 'Forks'], dtype=object)

# %%
df['city'].value_counts()
# Out:
# Houston         232
# Chicago         168
# San Antonio     134
# Los Angeles     129
# Las Vegas       123
#                ...
# Onsted            1
# Horton            1
# Spring Arbor      1
# Morenci           1
# Forks             1
# Name: city, Length: 7286, dtype: int64

# %%
#!Balnks, NULL, NA instead of NaN

# %%
df['open_hours'].fillna(df.mode()['open_hours'],inplace=True)

# %%
df['open_hours'].mode()
# df[df['open_hours'].isnull()]
# Out:
# 0    Sunday 9:00 AM - 10:00 PM, Monday 7:00 AM - 10...
# dtype: object

# %%
df.head()
# Out:
#    index    name                                                url  \
# 0      0  Subway  http://order.subway.com/Stores/Redirect.aspx?s...
# 1      1  Subway  http://order.subway.com/Stores/Redirect.aspx?s...
# 2      2  Subway  http://order.subway.com/Stores/Redirect.aspx?s...
# 3      3  Subway  http://order.subway.com/Stores/Redirect.aspx?s...
# 4      4  Subway  http://order.subway.com/Stores/Redirect.aspx?s...
#
#                                    street_address        city state zip_code  \
# 0                           1800 Duke St, Ste 100  Alexandria    VA    22314
# 1                                   1512 King St,  Alexandria    VA    22301
# 2                            2361 Eisenhower Ave,  Alexandria    VA    22314
# 3                      320 King Street, 1st Floor  Alexandria    VA    22314
# 4  5836 N. Kings Hwy, Suite A, Huntington Station  Alexandria    VA    22303
#
#   country  phone_number_1  phone_number_2  ...  email_2  website  \
# ...
