# %%
import pandas as pd
df=pd.read_csv('course_data_clean.csv')
df.head()
# Out:
#   course_code                        course_title  num_ratings useful easy  \
# 0      CS 115  Introduction to Computer Science 1         2111    21%  10%
# 1      CS 115  Introduction to Computer Science 1         2111    21%  10%
# 2      CS 115  Introduction to Computer Science 1         2111    21%  10%
# 3      CS 115  Introduction to Computer Science 1         2111    21%  10%
# 4      CS 115  Introduction to Computer Science 1         2111    21%  10%
#
#   liked  num_reviews                                            reviews  \
# 0   23%           86                    go to office hours and practice
# 1   23%           86  One of my least favourite courses. Although th...
# 2   23%           86  It starts with a very low pace but after midte...
# 3   23%           86  Took this in 2018 with no programming experien...
# 4   23%           86  I loved everything about cs 115. Great instruc...
#
#      course_rating  course_rating_int
# 0     liked course                1.0
# ...

# %%
pattern = '[0-9]'
df[df['course_title'].str.contains(pattern)]
df[df['course_title'].str.contains("Computer", case=False, na=False)]
df[df['course_title'].str.startswith("Intro")]
df[df['course_code'].isin(["CS 115"])]
# Out:
#       course_code                                       course_title  \
# 0          CS 115                 Introduction to Computer Science 1
# 1          CS 115                 Introduction to Computer Science 1
# 2          CS 115                 Introduction to Computer Science 1
# 3          CS 115                 Introduction to Computer Science 1
# 4          CS 115                 Introduction to Computer Science 1
# ...           ...                                                ...
# 14753  KOREA 301R                                Third-Year Korean 1
# 14772    PHYS 701                                Quantum Mechanics 1
# 14798     SI 250R  The History of Islamic Civilization from Late ...
# 14799     SI 251R  The History of Islamic Civilization from 1300-...
# 14833    ASL 102R                           American Sign Language 2
#
#        num_ratings useful  easy liked  num_reviews  \
# 0             2111    21%   10%   23%           86
# ...

# %%
df.shape
# Out:
# (14838, 10)
